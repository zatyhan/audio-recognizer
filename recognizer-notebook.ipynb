# %% [markdown]
# ## Draft Notebook for audio recognizer project
#
# For rought test, idea bin, etc..

# %%
import librosa
import numpy as np
import librosa.display
import matplotlib.pyplot as plt

# Load audio file
audio_path = '/Users/nureizzatyhamzaid/projects/audio-recognizer/test_audio.mp3'
waveform, sr = librosa.load(audio_path)

# %% [markdown]
# ### Assesing youtube playlist waveform pattern
#
# Check if there's any distinctive feature of the waveform.
#
# Result: Based on waveform chunks separated by apparent discontinuities, there's 12 songs but in reality there's only 9 songs.

# %%
# Display waveform
plt.figure(figsize=(14, 5))
librosa.display.waveshow(waveform, sr=sr)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Waveform')
plt.show()

# %%
# import librosa.onset

# # Perform onset detection
# onsets = librosa.onset.onset_detect(y=waveform, sr=sr, units='time')

# # Plot the onsets
# plt.figure(figsize=(10, 4))
# plt.plot(waveform)
# plt.vlines(librosa.frames_to_time(onsets), np.min(waveform), np.max(waveform), color='r', linestyle='--', label='Onsets')
# plt.xlabel('Time (s)')
# plt.ylabel('Amplitude')
# plt.title('Onsets')
# plt.legend()
# plt.show()
# Out:
# /Users/nureizzatyhamzaid/opt/anaconda3/envs/shazam/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np

# Compute STFT
stft = librosa.stft(np.abs(waveform), center=False)

plt.figure(figsize=(14, 5))
librosa.display.specshow(librosa.amplitude_to_db(stft, ref=np.max), sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
# Out:
# /var/folders/kq/fq_t9b_94kl8qw825dmz59280000gn/T/ipykernel_13748/307143533.py:7: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   librosa.display.specshow(librosa.amplitude_to_db(stft, ref=np.max), sr=sr, x_axis='time', y_axis='log')
# Text(0.5, 1.0, 'Spectrogram')

# %%
# onset_env= librosa.onset.onset_strength(y=waveform, sr=sr, aggregate=np.median)
# tempo, beats = librosa.beat.beat_track(onset_envelope=onset_env, sr=sr, hop_length=512)
# times= librosa.times_like(onset_env, sr=sr)
# plt.figure(figsize=(14, 5))
# plt.plot(times, librosa.util.normalize(onset_env), label='Onset strength')
# plt.vlines(librosa.frames_to_time(beats, sr=sr), 0, 1, color='r', alpha=0.75, linestyle='--', label='Beats')
# # plt.axhline( tempo, color='b', linestyle='-', label='Tempo (BPM)')
# plt.xlabel('Time (s)')
# plt.ylabel('Amplitude')
# plt.legend()

# %%
# ac= librosa.autocorrelate(waveform, max_size=10000)

# %%
plt.plot(librosa.autocorrelate(waveform))
# plt.set_xlim([2, 1750])
